# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
from seaborn import  load_dataset

# %%
df = load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(data=df, x="survived")
plt.show()

# %%
sns.countplot(data=df, x="sex")
plt.show()

# %%
sns.countplot(data=df, x="class")
plt.show()

# %%
sns.countplot(data=df, x="who")
plt.show()

# %%
sns.countplot(x="embark_town", data=df)
plt.show()

# %%
sns.barplot(x="class", y="fare", data=df)
plt.show()

# %%
sns.barplot(x="survived", y="fare", data=df)
plt.show()

# %%
sns.barplot(x="survived", y="fare", data=df, hue="who")
plt.show()

# %%
sns.barplot(x="survived", y="fare", data=df, hue="embarked")
plt.show()

# %%
sns.barplot(x="survived", y="fare", data=df, hue="sibsp")
plt.show()

# %%
sns.barplot(x="survived", y="fare", data=df, hue="age")
plt.show()

# %%
sns.histplot(data=df, x="age")
plt.show()

# %%
sns.scatterplot(data=df, x="age", y="fare", hue="survived")
plt.show()

# %%
sns.scatterplot(data=df, x="age", y="fare", hue="who")
plt.show()

# %%
sns.boxenplot(data=df, x="age", y="fare")
plt.show()
sns.boxenplot(data=df, x="age", y="fare", hue="who")
plt.show()

# %%
df_index = df['survived'].value_counts().index
df_values = df['survived'].value_counts().values

# %%
df_index
df_values
# Out:
# array([549, 342])

# %%
sns.pairplot(df, hue="survived")
plt.show()

# %%
plt.pie(df_values, labels=df_index, autopct='%1.1f%%', startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f137bdcee70>,
# ...
#  [Text(-1.0275626831463007, -0.39257474728410047, '0'),
#   Text(1.027562555229157, 0.39257508210650083, '1')],
#  [Text(-0.5604887362616185, -0.21413168033678204, '61.6%'),
#   Text(0.560488666488631, 0.21413186296718226, '38.4%')])

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_11007/3052501683.py in ?()
# ----> 1 plt.pie(df, labels=df_index, autopct='%1.1f%%', startangle=90)
#
# ~/miniconda3/lib/python3.12/site-packages/matplotlib/_api/deprecation.py in ?(*args, **kwargs)
#     449                 since, message="Passing the %(name)s %(obj_type)s "
#     450                 "positionally is deprecated since Matplotlib %(since)s; the "
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#
# ...

# %%
sns.lineplot(data=df, x="age", y="fare", hue="survived")
plt.show()
sns.lineplot(data=df, x="age", y="fare", hue="who")
plt.show()
sns.lineplot(data=df, x="age", y="fare", hue="class")
plt.show()
